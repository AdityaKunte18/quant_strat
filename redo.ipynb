# %%
import pandas as pd

df = pd.read_csv('cleaned_data.csv')

df = df[['Symbol', 'ROE', 'SE', 'Net Income']]
df.to_csv("cleanish.csv", index=False)

# %%
import pandas as pd
import yfinance as yf


df = pd.read_csv('cleanish.csv')


start_date = '2022-01-01'
end_date = '2023-12-31'


stock_prices_df = pd.DataFrame()


for symbol in df['Symbol']:
    
    stock_data = yf.download(symbol, start=start_date, end=end_date)
    
    
    adj_close_prices = stock_data['Adj Close'].reset_index()
    
    
    adj_close_prices['Date'] = adj_close_prices['Date'].dt.strftime('%Y-%m-%d')
    
    
    adj_close_prices_pivot = adj_close_prices.pivot_table(index=None, columns='Date', values='Adj Close')
    
    
    adj_close_prices_pivot['Symbol'] = symbol
    
    
    stock_prices_df = pd.concat([stock_prices_df, adj_close_prices_pivot], ignore_index=True)


final_df = pd.merge(df, stock_prices_df, on='Symbol', how='left')


final_df.to_csv('cleaned_data_with_prices.csv', index=False)

print("Stock prices added successfully!")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
stock_data = yf.download('AAPL', start=start_date, end=end_date)
adj_close_prices = stock_data['Adj Close'].reset_index()
stock_data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  179.273621
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  176.998337
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  172.290192
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  169.414093
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  169.581543
# ...                ...         ...         ...         ...         ...
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  192.868149
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  192.320221
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  192.419830
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  192.848206
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  191.802185
#
#                Volume
# Date
# ...

# %%
cleaned_data.to_csv('meow.csv', index=False)

# %%
import pandas as pd

# Load the stocks data
stocks = pd.read_csv('cleaned_data.csv')

# Create the first DataFrame with 'Symbol' and 'momentum' columns
df1 = pd.DataFrame()
df1['Symbol'] = stocks['Symbol']
df1['momentum'] = 0  # Initialize momentum with a default value (e.g., 0)

# Extract the relevant date columns from the stocks DataFrame
date_columns = stocks.loc[:, '2022-01-03':'2022-12-30']

# Calculate the standard deviation across the selected date columns for each row (stock)
df1['daily standard deviation'] = date_columns.std(axis=1)

# Calculate momentum as (price on '2023-06-01' - price on '2023-01-04') / price on '2023-06-01'
df1['momentum'] = (stocks['2023-06-01'] - stocks['2023-01-04']) / stocks['2023-01-04']

# Display the updated DataFrame
df1.head()
# Out:
#   Symbol  momentum  daily standard deviation
# 0    WFC -0.047341                  4.577515
# 1   QCOM  0.052155                 18.806288
# 2    TXN  0.054715                  8.740996
# 3     GE  0.492408                  7.022925
# 4    IBM -0.065873                  7.440575
